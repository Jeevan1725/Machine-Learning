# %%
#preprocessing for netwrotk traffic EVSE-A(all files in the directory)

import pandas as pd
import os
import re

# Base directory for CSV files
base_dir = r"J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv"

# Get all CSV files in the directory
file_paths = []
for file_name in os.listdir(base_dir):
    if file_name.endswith('.csv'):
        # Extract attack type from file name
        attack_type = re.sub(r'EVSE-B-(charging|idle)-', '', file_name).replace('.csv', '').replace('-', ' ').title()
        file_paths.append({"file": os.path.join(base_dir, file_name), "attack_type": attack_type})

# Preprocessing function
def preprocess_network_traffic(file_path, attack_type):
    try:
        # Load CSV with auto-detection of delimiters
        df = pd.read_csv(file_path, engine='python', on_bad_lines='skip')
        
        # Ensure the file has data
        if df.empty:
            print(f'Skipping empty file: {file_path}')
            return
        
        # Check number of columns
        print(f"Columns detected in {file_path}: {df.columns.tolist()}")
        print(df.head())
        
        # If only one column, assume data is space or tab delimited
        if len(df.columns) == 1:
            df = df.iloc[:, 0].str.split(expand=True)
        
        # Adjust column renaming based on detected structure
        num_cols = len(df.columns)
        if num_cols >= 4:
            df.columns = ['time', 'counts', 'unit', 'events'] + [f'extra_col_{i}' for i in range(5, num_cols + 1)]
        else:
            print(f"Unexpected column structure in {file_path}, skipping.")
            return
        
        # Convert 'time' and 'counts' to numeric
        df['time'] = pd.to_numeric(df['time'], errors='coerce')
        df['counts'] = pd.to_numeric(df['counts'], errors='coerce')
        
        # Add attack type column
        df['attack_type'] = attack_type

        # Feature engineering: rolling averages and derivatives
        df['rolling_avg_counts'] = df['counts'].rolling(window=10).mean().fillna(0)
        df['counts_derivative'] = df['counts'].diff().fillna(0)

        # Time-based features
        df['time_diff'] = df['time'].diff().fillna(0)
        df['packets_per_second'] = df['counts'] / df['time_diff'].replace(0, 1)

        # Save preprocessed data to the same location
        output_file = os.path.join(os.path.dirname(file_path), 'Preprocessed_' + os.path.basename(file_path))
        df.to_csv(output_file, index=False)
        print(f"Preprocessed file saved to: {output_file}")
    except Exception as e:
        print(f'Error processing {file_path}: {e}')

# Apply preprocessing to all files
for file_info in file_paths:
    preprocess_network_traffic(file_info['file'], file_info['attack_type'])
# Out:
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-charging-aggressive-scan.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 1   1              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 2   2              0  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32
# 3   3              0            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32
# 4   4              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     33682            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32        22
# 1     47450            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32        22
# 2     49152  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32     34084
# 3     33234             192.168.137.87  dc:a6:32:c9:e5:3e  dc:a6:32      8765
# 4     50534            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32       139
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    1               SSH               RemoteAccess
# 1  ...                    0               SSH               RemoteAccess
# 2  ...                    0               TLS                        Web
# 3  ...                    0           Unknown                Unspecified
# 4  ...                    0           NetBIOS                     System
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       1                       1                    NaN
# 2                       0                       6                    NaN
# 3                       0                       0                    NaN
# 4                       1                       1                    NaN
#
#                  client_fingerprint                server_fingerprint  \
# 0  E788C657D1A22971D5026526FFD2E918  41FF3ECD1458B0BF86E1B4891636213E
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    user_agent  content_type
# 0         NaN           NaN
# 1         NaN           NaN
# 2         NaN           NaN
# 3         NaN           NaN
# 4         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-charging-aggressive-scan.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-charging-icmp-flood.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32
# 1   1              0            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32
# 2   2              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 3   3              0  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32
# 4   4              0            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     34084  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32     49152
# 1     33234             192.168.137.87  dc:a6:32:c9:e5:3e  dc:a6:32      8765
# 2         0            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32         0
# 3         0                    ff02::2  33:33:00:00:00:02  33:33:00         0
# 4     51650              192.168.137.1  8c:ae:4c:dd:1e:39  8c:ae:4c        53
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    0           Unknown                Unspecified
# 2  ...                    0              ICMP                    Network
# 3  ...                    0            ICMPV6                    Network
# 4  ...                    0     DNS.UbuntuONE                    Network
#
#    application_is_guessed  application_confidence  \
# 0                       0                       6
# 1                       0                       0
# 2                       0                       6
# 3                       0                       6
# 4                       0                       6
#
#            requested_server_name  client_fingerprint  server_fingerprint  \
# 0                            NaN                 NaN                 NaN
# 1                            NaN                 NaN                 NaN
# 2                            NaN                 NaN                 NaN
# 3                            NaN                 NaN                 NaN
# 4  connectivity-check.ubuntu.com                 NaN                 NaN
#
#    user_agent  content_type
# 0         NaN           NaN
# 1         NaN           NaN
# 2         NaN           NaN
# 3         NaN           NaN
# 4         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-charging-icmp-flood.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-charging-os-fingerprinting.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32
# 1   1              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 2   2              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 3   3              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 4   4              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     49152  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32     34084
# 1     36218            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
# 2     36219            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
# 3     36220            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
# 4         0            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32         0
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    0               SSH               RemoteAccess
# 2  ...                    0               SSH               RemoteAccess
# 3  ...                    0               SSH               RemoteAccess
# 4  ...                    0              ICMP                    Network
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       1                       1                    NaN
# 2                       1                       1                    NaN
# 3                       1                       1                    NaN
# 4                       0                       6                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-charging-os-fingerprinting.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-charging-port-scan.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32
# 1   1              0            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32
# 2   2              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 3   3              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 4   4              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     34084  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32     49152
# 1     33234             192.168.137.87  dc:a6:32:c9:e5:3e  dc:a6:32      8765
# 2     48934            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32      3389
# 3     48934            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32      1025
# 4     48934            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32        23
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    0           Unknown                Unspecified
# 2  ...                    0               RDP               RemoteAccess
# 3  ...                    0           Unknown                Unspecified
# 4  ...                    0            Telnet               RemoteAccess
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       0                       0                    NaN
# 2                       1                       1                    NaN
# 3                       0                       0                    NaN
# 4                       1                       1                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-charging-port-scan.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-charging-push-ack-flood.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32
# 1   1              0            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32
# 2   2              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 3   3              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 4   4              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     49152  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32     34084
# 1     33234             192.168.137.87  dc:a6:32:c9:e5:3e  dc:a6:32      8765
# 2      1853            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
# 3      1854            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
# 4      1855            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    2           Unknown                Unspecified
# 2  ...                    0               SSH               RemoteAccess
# 3  ...                    0               SSH               RemoteAccess
# 4  ...                    0               SSH               RemoteAccess
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       0                       0                    NaN
# 2                       1                       1                    NaN
# 3                       1                       1                    NaN
# 4                       1                       1                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-charging-push-ack-flood.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-charging-service-detection-scan.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id          src_ip            src_mac   src_oui  src_port  \
# 0   0              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     33389
# 1   1              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     33389
# 2   2              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     33389
# 3   3              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     33389
# 4   4              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     33389
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0  192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32       554  ...
# 1  192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32       995  ...
# 2  192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32       445  ...
# 3  192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32        80  ...
# 4  192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32        53  ...
#
#    dst2src_fin_packets  application_name  application_category_name  \
# 0                    0              RTSP                      Media
# 1                    0              POPS                      Email
# 2                    0            SMBv23                     System
# 3                    0              HTTP                        Web
# 4                    0               DNS                    Network
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       1                       1                    NaN
# 1                       1                       1                    NaN
# 2                       1                       1                    NaN
# 3                       1                       1                    NaN
# 4                       1                       1                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-charging-service-detection-scan.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-charging-syn-flood.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32
# 1   1              0            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32
# 2   2              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 3   3              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 4   4              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     34084  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32     49152
# 1     42376             192.168.137.87  dc:a6:32:c9:e5:3e  dc:a6:32      8765
# 2      2569            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32        22
# 3      2570            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32        22
# 4      2571            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32        22
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    2           Unknown                Unspecified
# 2  ...                    0               SSH               RemoteAccess
# 3  ...                    0               SSH               RemoteAccess
# 4  ...                    0               SSH               RemoteAccess
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       0                       0                    NaN
# 2                       1                       1                    NaN
# 3                       1                       1                    NaN
# 4                       1                       1                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-charging-syn-flood.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-charging-syn-stealth.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32
# 1   1              0            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32
# 2   2              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 3   3              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 4   4              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     34084  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32     49152
# 1     33234             192.168.137.87  dc:a6:32:c9:e5:3e  dc:a6:32      8765
# 2     61045            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32       256
# 3     61045            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32        25
# 4     61045            192.168.137.198  dc:a6:32:c9:e5:5e  dc:a6:32       139
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    0           Unknown                Unspecified
# 2  ...                    0           Unknown                Unspecified
# 3  ...                    0              SMTP                      Email
# 4  ...                    0           NetBIOS                     System
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       0                       0                    NaN
# 2                       0                       0                    NaN
# 3                       1                       1                    NaN
# 4                       1                       1                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-charging-syn-stealth.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-charging-synonymous-ip-flood.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32
# 1   1              0            192.168.137.198  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 2   2              0            192.168.137.198  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 3   3              0            192.168.137.198  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 4   4              0            192.168.137.198  a8:6b:ad:1f:9b:e5  a8:6b:ad
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     34084  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32     49152
# 1      1329            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
# 2      1330            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
# 3      1331            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
# 4      1332            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    0               SSH               RemoteAccess
# 2  ...                    0               SSH               RemoteAccess
# 3  ...                    0               SSH               RemoteAccess
# 4  ...                    0               SSH               RemoteAccess
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       1                       1                    NaN
# 2                       1                       1                    NaN
# 3                       1                       1                    NaN
# 4                       1                       1                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-charging-synonymous-ip-flood.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-charging-tcp-flood.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32
# 1   1              0            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32
# 2   2              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 3   3              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
# 4   4              0             192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     49152  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32     34084
# 1     42376             192.168.137.87  dc:a6:32:c9:e5:3e  dc:a6:32      8765
# 2      1926            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
# 3      1927            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
# 4      1928            192.168.137.198  dc:a6:32:c9:e5:5f  dc:a6:32        22
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    0           Unknown                Unspecified
# 2  ...                    0               SSH               RemoteAccess
# 3  ...                    0               SSH               RemoteAccess
# 4  ...                    0               SSH               RemoteAccess
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       0                       0                    NaN
# 2                       1                       1                    NaN
# 3                       1                       1                    NaN
# 4                       1                       1                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-charging-tcp-flood.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-charging-udp-flood.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32
# ...
# 3   3              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
# 4   4              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     49152  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32     41856
# 1     35581               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32       445
# 2     35581               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32        25
# 3     35581               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32      1720
# 4     35581               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32        23
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    0            SMBv23                     System
# 2  ...                    0              SMTP                      Email
# 3  ...                    0              H323                       VoIP
# 4  ...                    0            Telnet               RemoteAccess
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       1                       1                    NaN
# 2                       1                       1                    NaN
# 3                       1                       1                    NaN
# 4                       1                       1                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-MaliciousEV-port-scan.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-MaliciousEV-service-detection.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32
# 1   1              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
# 2   2              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
# 3   3              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
# 4   4              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     52574  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32     49152
# 1     65172               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32       554
# 2     65172               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32        80
# 3     65172               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32        22
# 4     65172               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32       199
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    0              RTSP                      Media
# 2  ...                    0              HTTP                        Web
# 3  ...                    0               SSH               RemoteAccess
# 4  ...                    0           Unknown                Unspecified
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       1                       1                    NaN
# 2                       1                       1                    NaN
# 3                       1                       1                    NaN
# 4                       0                       0                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-MaliciousEV-service-detection.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-MaliciousEV-syn-stealth-scan.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32
# 1   1              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
# 2   2              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
# 3   3              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
# 4   4              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     52574  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32     49152
# 1     55760               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32       995
# 2     55760               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32       135
# 3     55760               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32      3306
# 4     55760               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32       199
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    0              POPS                      Email
# 2  ...                    0               RPC                        RPC
# 3  ...                    0             MySQL                   Database
# 4  ...                    0           Unknown                Unspecified
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       1                       1                    NaN
# 2                       1                       1                    NaN
# 3                       1                       1                    NaN
# 4                       0                       0                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-MaliciousEV-syn-stealth-scan.csv
# Columns detected in J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\EVSE-B-MaliciousEV-vulnerability-scan.csv: ['id', 'expiration_id', 'src_ip', 'src_mac', 'src_oui', 'src_port', 'dst_ip', 'dst_mac', 'dst_oui', 'dst_port', 'protocol', 'ip_version', 'vlan_id', 'tunnel_id', 'bidirectional_first_seen_ms', 'bidirectional_last_seen_ms', 'bidirectional_duration_ms', 'bidirectional_packets', 'bidirectional_bytes', 'src2dst_first_seen_ms', 'src2dst_last_seen_ms', 'src2dst_duration_ms', 'src2dst_packets', 'src2dst_bytes', 'dst2src_first_seen_ms', 'dst2src_last_seen_ms', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes', 'bidirectional_min_ps', 'bidirectional_mean_ps', 'bidirectional_stddev_ps', 'bidirectional_max_ps', 'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps', 'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps', 'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms', 'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms', 'bidirectional_max_piat_ms', 'src2dst_min_piat_ms', 'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms', 'src2dst_max_piat_ms', 'dst2src_min_piat_ms', 'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms', 'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_cwr_packets', 'bidirectional_ece_packets', 'bidirectional_urg_packets', 'bidirectional_ack_packets', 'bidirectional_psh_packets', 'bidirectional_rst_packets', 'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_cwr_packets', 'src2dst_ece_packets', 'src2dst_urg_packets', 'src2dst_ack_packets', 'src2dst_psh_packets', 'src2dst_rst_packets', 'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_cwr_packets', 'dst2src_ece_packets', 'dst2src_urg_packets', 'dst2src_ack_packets', 'dst2src_psh_packets', 'dst2src_rst_packets', 'dst2src_fin_packets', 'application_name', 'application_category_name', 'application_is_guessed', 'application_confidence', 'requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']
#    id  expiration_id                     src_ip            src_mac   src_oui  \
# 0   0              0  fe80::813f:cb21:c6d4:b7c2  dc:a6:32:c9:e5:5e  dc:a6:32
# 1   1              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
# 2   2              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
# 3   3              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
# 4   4              0               192.168.10.4  dc:a6:32:c9:e6:9f  dc:a6:32
#
#    src_port                     dst_ip            dst_mac   dst_oui  dst_port  \
# 0     49152  fe80::6c9b:9e0d:591c:fc8a  dc:a6:32:c9:e6:9f  dc:a6:32     52574
# 1     42849               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32       111
# 2     42849               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32      1723
# 3     42849               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32      8888
# 4     42849               192.168.10.2  dc:a6:32:c9:e5:5e  dc:a6:32       445
#
#    ...  dst2src_fin_packets  application_name  application_category_name  \
# 0  ...                    0               TLS                        Web
# 1  ...                    0           Unknown                Unspecified
# 2  ...                    0           Unknown                Unspecified
# 3  ...                    0           Unknown                Unspecified
# 4  ...                    0            SMBv23                     System
#
#    application_is_guessed  application_confidence  requested_server_name  \
# 0                       0                       6                    NaN
# 1                       0                       0                    NaN
# 2                       0                       0                    NaN
# 3                       0                       0                    NaN
# 4                       1                       1                    NaN
#
#    client_fingerprint  server_fingerprint  user_agent  content_type
# 0                 NaN                 NaN         NaN           NaN
# 1                 NaN                 NaN         NaN           NaN
# 2                 NaN                 NaN         NaN           NaN
# 3                 NaN                 NaN         NaN           NaN
# 4                 NaN                 NaN         NaN           NaN
#
# [5 rows x 86 columns]
# Preprocessed file saved to: J:\\R JEEVAN\B.TECH CYS\\4th Sem\\Machine Learning\\ML Project\\CICEVSE2024_Dataset\\Network Traffic\\EVSE-B\\csv\Preprocessed_EVSE-B-MaliciousEV-vulnerability-scan.csv
